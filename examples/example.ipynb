# %%
import sys
sys.path.insert(0, '../')
import argparse
import os
import pheflux
# Out:
# Welcome to PheFlux !

# %%
inputFile       = "./data/InputData_example.csv"  # Name of the csv file with required information
resultsDir      = "./results" # Name of the directory where output files will be stored
verbosity       = True # Verbose mode
prefix_log_file = "example"  # Prefix log output file.

# %%
pheflux.getFluxes(inputFile,resultsDir,prefix_log_file,verbosity)
# Out:
# [2022/9/5 16:32:2] Condition ejecuted: Scerevisiae - Glucose
# [2022/9/5 16:32:2] Loading metabolic model: iMM904
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# [2022/9/5 16:32:4] Loading transcriptomic data...
# [2022/9/5 16:32:4] Updating metabolic model...
# [2022/9/5 16:32:5] Running pheflux...
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# Total number of variables............................:     2072
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     2072
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1227
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
#
# Number of Iterations....: 1980
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.5492936068903718e+03   -4.5492936068903718e+03
# Dual infeasibility......:   3.4448424951557741e-11    3.4448424951557741e-11
# Constraint violation....:   5.5412570525239982e-11    5.5412570525239982e-11
# Complementarity.........:   2.5059035597444061e-09    2.5059035597444061e-09
# Overall NLP error.......:   2.5059035597444061e-09    2.5059035597444061e-09
#
#
# Number of objective function evaluations             = 2542
# Number of objective gradient evaluations             = 1962
# Number of equality constraint evaluations            = 2542
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1983
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1980
# Total CPU secs in IPOPT (w/o function evaluations)   =     11.998
# Total CPU secs in NLP function evaluations           =      1.151
#
# EXIT: Optimal Solution Found.
#            F  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 340.00ms (133.75us) 340.17ms (133.82us)      2542
#        nlp_g  | 230.00ms ( 90.48us) 204.78ms ( 80.56us)      2542
#   nlp_grad_f  | 350.00ms (178.30us) 295.33ms (150.45us)      1963
#   nlp_hess_l  | 100.00ms ( 50.56us)  52.60ms ( 26.59us)      1978
#    nlp_jac_g  | 190.00ms ( 95.77us) 213.68ms (107.70us)      1984
#        total  |  13.64 s ( 13.64 s)  13.54 s ( 13.54 s)         1
#
# [2022/9/5 16:32:25] Saving metabolic fluxes...
# [2022/9/5 16:32:25] Scerevisiae - Glucose ... is processed.
#
#  ====================================== o =======================================
#
# [2022/9/5 16:32:25] Condition ejecuted: Ecoli - Glucose
# [2022/9/5 16:32:25] Loading metabolic model: iJO1366
# [2022/9/5 16:32:28] Loading transcriptomic data...
# [2022/9/5 16:32:28] Updating metabolic model...
# [2022/9/5 16:32:30] Running pheflux...
#
# Total number of variables............................:     3209
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:     3209
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     1806
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
#
# Number of Iterations....: 407
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -1.0407420694343904e+04   -1.0407420694343904e+04
# Dual infeasibility......:   5.9350463391977813e-07    5.9350463391977813e-07
# Constraint violation....:   7.3057626821999393e-12    7.3057626821999393e-12
# Complementarity.........:   2.5059035596801342e-09    2.5059035596801342e-09
# Overall NLP error.......:   5.9350463391977813e-07    5.9350463391977813e-07
#
#
# Number of objective function evaluations             = 474
# Number of objective gradient evaluations             = 406
# Number of equality constraint evaluations            = 474
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 409
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 407
# Total CPU secs in IPOPT (w/o function evaluations)   =      3.277
# Total CPU secs in NLP function evaluations           =      0.349
#
# EXIT: Solved To Acceptable Level.
#            F  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 110.00ms (232.07us) 102.72ms (216.71us)       474
#        nlp_g  |  50.00ms (105.49us)  52.69ms (111.16us)       474
#   nlp_grad_f  | 140.00ms (343.98us)  99.10ms (243.49us)       407
#   nlp_hess_l  |  10.00ms ( 24.63us)  16.83ms ( 41.45us)       406
#    nlp_jac_g  |  90.00ms (219.51us)  63.47ms (154.79us)       410
#        total  |   3.74 s (  3.74 s)   3.71 s (  3.71 s)         1
#
# [2022/9/5 16:32:45] Saving metabolic fluxes...
# [2022/9/5 16:32:45] Ecoli - Glucose ... is processed.
#
#  ====================================== o =======================================
#
# [2022/9/5 16:32:45] Condition ejecuted: Homo_sapiens - PrimaryTumor_StageIIIA
# [2022/9/5 16:32:45] Loading metabolic model: Recon3D
# [2022/9/5 16:32:56] Loading transcriptomic data...
# [2022/9/5 16:32:56] Updating metabolic model...
# [2022/9/5 16:33:28] Running pheflux...
#
# Total number of variables............................:    14321
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:    14321
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     5836
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
#
# Number of Iterations....: 1987
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.3900325240510156e+03   -4.3900325240510156e+03
# Dual infeasibility......:   4.9867696139940194e-12    4.9867696139940194e-12
# Constraint violation....:   3.2375959953167971e-11    3.2375959953167971e-11
# Complementarity.........:   2.5059035596814163e-09    2.5059035596814163e-09
# Overall NLP error.......:   2.5059035596814163e-09    2.5059035596814163e-09
#
#
# Number of objective function evaluations             = 2323
# Number of objective gradient evaluations             = 1982
# Number of equality constraint evaluations            = 2323
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 1989
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 1987
# Total CPU secs in IPOPT (w/o function evaluations)   =     71.827
# Total CPU secs in NLP function evaluations           =      7.629
#
# EXIT: Optimal Solution Found.
#            F  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.13 s (916.92us)   2.15 s (925.29us)      2323
#        nlp_g  | 910.00ms (391.73us)   1.10 s (475.49us)      2323
#   nlp_grad_f  |   2.14 s (  1.08ms)   2.09 s (  1.05ms)      1983
#   nlp_hess_l  | 350.00ms (176.23us) 439.58ms (221.34us)      1986
#    nlp_jac_g  |   1.63 s (819.10us)   1.53 s (770.80us)      1990
#        total  |  80.37 s ( 80.37 s)  79.79 s ( 79.79 s)         1
#
# [2022/9/5 16:36:8] Saving metabolic fluxes...
# [2022/9/5 16:36:8] Homo_sapiens - PrimaryTumor_StageIIIA ... is processed.
#
#  ====================================== o =======================================
#
# Average time per optimization: 32.351193030675255 s
# Average time per condition: 76.67310778299968 s
# Total process time: 4.112976523240407 min --> ~ 0.06854960872067345 h
# R_24_25DHVITD3tm         8.676292e-06
# R_25HVITD3t              6.078262e-03
# R_COAtl                  5.549851e-03
# R_EX_5adtststerone_e     5.505000e-05
# R_EX_5adtststerones_e    1.317868e-04
#                              ...
# R_ACMPGLUTTRsc           9.895148e-09
# R_FVSCOAhc               3.356451e-09
# R_MDZGLChr               0.000000e+00
# R_TMACMPhr               2.601476e-08
# R_CYSACMPitr             9.895148e-09
# Length: 10600, dtype: float64
